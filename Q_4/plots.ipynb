# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_DIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIRO_predict")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_RIRO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIRO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_RIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIDO_predict")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in us)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_RIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIDO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_DIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIDO_predict")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_DIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIDO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_DIRO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIRO_predict_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in us)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/results_DIRO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIRO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in us)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Standard Deviation Plots

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_results_DIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIDO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_results_DIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIDO_predict_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_results_RIRO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIRO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in us)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_results_RIRO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIRO_predict_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in us)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_results_RIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIDO_predict_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in us)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_results_RIDO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("RIDO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_dev/std_results_DIRO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in predict_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIRO_predict_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import json
import matplotlib.pyplot as plt


json_path = "C:/Users/OM/Downloads/assignment-1-ml-doofenshmirtz-evil-inc/Q_4/std_dev/std_results_DIRO.json"
with open(json_path, "r") as f:
    data = json.load(f)
    learning_times = data["learning_times"]
    predict_times = data["predict_times"]
z = []
for i in learning_times:
    for j in range(len(i)):
        i[j] = i[j] * 1000
    z.extend(i)

## X==N
## Y==P
x = []
y = []
for j in range(1, 7):
    for i in range(6, 42):
        x.append(j)
for j in range(1, 7):
    for i in range(6, 42):
        y.append(i)


        
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5)
plt.title("DIRO_learning_time")
plt.xlabel("N")
plt.ylabel("M")
# plt.("Time(in us)")
ax.set_zlabel("Time(in s)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
